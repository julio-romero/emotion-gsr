# %%
from emotiongsr import DataProcessor

# %%
IMOTIONS_PATH = 'Data'
IMAGES_PATH = 'Images'
OUTPUT_PATH = 'CleanedData'

# %%
processor = DataProcessor(IMOTIONS_PATH,IMAGES_PATH,OUTPUT_PATH)

# %%
data = processor.get_clean_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = processor.get_clean_data()
#
# File m:\emotion-gsr\emotiongsr\dataprocessor.py:86, in DataProcessor.get_clean_data(self)
#      67 """
#      68 This method loads the cleaned data from the folder, then
#      69 concats all of them into a single dataframe with the timestamp
#    (...)
#      83     ValueError: if you havent called the method clean_files first
#      84 """
#      85 if not self.data_is_clean:
# ---> 86     raise ValueError("Clean the data first")
#      87 dataframes = self.__load_clean_data()
#      88 # Convert 'Timestamp' to datetime type and set it as index
#
# ValueError: Clean the data first

# %%
processor.clean_files()

# %%
data = processor.get_clean_data()
data
# Out:
#                                  Row   StimType  Duration SourceStimuliName  \
# Timestamp
# 1970-01-01 00:00:00.000000327     10  TestImage    6000.0         1920_7.90
# 1970-01-01 00:00:00.000000328     11        NaN       NaN         1920_7.90
# 1970-01-01 00:00:00.000000335     12        NaN       NaN         1920_7.90
# 1970-01-01 00:00:00.000000343     13        NaN       NaN         1920_7.90
# 1970-01-01 00:00:00.000000351     14        NaN       NaN         1920_7.90
# ...                              ...        ...       ...               ...
# 1970-01-01 00:00:00.000091005  14392        NaN       NaN         1410_7.00
# 1970-01-01 00:00:00.000091013  14393        NaN       NaN         1410_7.00
# 1970-01-01 00:00:00.000091021  14394        NaN       NaN         1410_7.00
# 1970-01-01 00:00:00.000091028  14395        NaN       NaN         1410_7.00
# 1970-01-01 00:00:00.000091030  14396        NaN       NaN         1410_7.00
#
#                               CollectionPhase  SlideEvent Participant  \
# Timestamp
# 1970-01-01 00:00:00.000000327  StimuliDisplay  StartMedia          R2
# 1970-01-01 00:00:00.000000328             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000000335             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000000343             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000000351             NaN  StartMedia          R2
# ...                                       ...         ...         ...
# 1970-01-01 00:00:00.000091005             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000091013             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000091021             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000091028             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000091030             NaN  StartMedia          r3
#
#                                SampleNumber  SampleNumber.1  Anger  ...  \
# Timestamp                                                           ...
# 1970-01-01 00:00:00.000000327           NaN             NaN    NaN  ...
# 1970-01-01 00:00:00.000000328           NaN         75895.0    NaN  ...
# 1970-01-01 00:00:00.000000335           NaN         75896.0    NaN  ...
# 1970-01-01 00:00:00.000000343           NaN         75897.0    NaN  ...
# 1970-01-01 00:00:00.000000351           NaN         75898.0    NaN  ...
# ...                                     ...             ...    ...  ...
# 1970-01-01 00:00:00.000091005           NaN        110702.0    NaN  ...
# 1970-01-01 00:00:00.000091013           NaN        110703.0    NaN  ...
# 1970-01-01 00:00:00.000091021           NaN        110704.0    NaN  ...
# 1970-01-01 00:00:00.000091028           NaN        110705.0    NaN  ...
# 1970-01-01 00:00:00.000091030         179.0             NaN    NaN  ...
#
#                                Confusion  Neutral  GSR RAW  \
# Timestamp
# 1970-01-01 00:00:00.000000327        NaN      NaN      NaN
# 1970-01-01 00:00:00.000000328        NaN      NaN  35890.0
# 1970-01-01 00:00:00.000000335        NaN      NaN  35890.0
# 1970-01-01 00:00:00.000000343        NaN      NaN  35889.0
# 1970-01-01 00:00:00.000000351        NaN      NaN  35887.0
# ...                                  ...      ...      ...
# 1970-01-01 00:00:00.000091005        NaN      NaN  51574.0
# 1970-01-01 00:00:00.000091013        NaN      NaN  51573.0
# 1970-01-01 00:00:00.000091021        NaN      NaN  51571.0
# 1970-01-01 00:00:00.000091028        NaN      NaN  51575.0
# 1970-01-01 00:00:00.000091030        NaN      NaN      NaN
#
#                                GSR Resistance CAL  GSR Conductance CAL  \
# Timestamp
# 1970-01-01 00:00:00.000000327                 NaN                  NaN
# 1970-01-01 00:00:00.000000328          279.770445             3.574359
# 1970-01-01 00:00:00.000000335          279.770445             3.574359
# 1970-01-01 00:00:00.000000343          279.885175             3.572894
# 1970-01-01 00:00:00.000000351          280.114919             3.569963
# ...                                           ...                  ...
# 1970-01-01 00:00:00.000091005         1294.768612             0.772339
# 1970-01-01 00:00:00.000091013         1295.513374             0.771895
# 1970-01-01 00:00:00.000091021         1297.005471             0.771007
# 1970-01-01 00:00:00.000091028         1294.024706             0.772783
# 1970-01-01 00:00:00.000091030                 NaN                  NaN
#
#                                Heart Rate PPG ALG   GSR Raw  GSR Interpolated  \
# Timestamp
# 1970-01-01 00:00:00.000000327                 NaN       NaN               NaN
# 1970-01-01 00:00:00.000000328                93.0  3.574359          3.574359
# 1970-01-01 00:00:00.000000335                93.0  3.574359          3.574359
# 1970-01-01 00:00:00.000000343                93.0  3.572894          3.572894
# 1970-01-01 00:00:00.000000351                93.0  3.569963          3.569963
# ...                                           ...       ...               ...
# 1970-01-01 00:00:00.000091005                -1.0  0.772339          0.772339
# 1970-01-01 00:00:00.000091013                -1.0  0.771895          0.771895
# 1970-01-01 00:00:00.000091021                -1.0  0.771007          0.771007
# 1970-01-01 00:00:00.000091028                -1.0  0.772783          0.772783
# 1970-01-01 00:00:00.000091030                 NaN       NaN               NaN
#
#                                Tonic Signal  Phasic Signal
# Timestamp
# 1970-01-01 00:00:00.000000327           NaN            NaN
# 1970-01-01 00:00:00.000000328      3.574359       0.000093
# 1970-01-01 00:00:00.000000335      3.574359       0.000073
# 1970-01-01 00:00:00.000000343      3.572894       0.000057
# 1970-01-01 00:00:00.000000351      3.571429      -0.000116
# ...                                     ...            ...
# 1970-01-01 00:00:00.000091005      0.771895       0.000014
# 1970-01-01 00:00:00.000091013      0.771895       0.000060
# 1970-01-01 00:00:00.000091021      0.771895      -0.000051
# 1970-01-01 00:00:00.000091028      0.771895      -0.000040
# 1970-01-01 00:00:00.000091030           NaN            NaN
#
# [28435 rows x 29 columns]
