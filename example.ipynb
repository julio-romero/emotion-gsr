# %%
from emotiongsr import DataProcessor

# %%
IMOTIONS_PATH = 'Data'
IMAGES_PATH = 'Images'
OUTPUT_PATH = 'CleanedData'

# %%
processor = DataProcessor(IMOTIONS_PATH,IMAGES_PATH,OUTPUT_PATH)

# %%
data = processor.get_clean_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25642/426789281.py in <module>
# ----> 1 data = processor.get_clean_data()
#
# /mdrive/mr23768/emotion-gsr/emotiongsr/dataprocessor.py in get_clean_data(self)
#     116         """
#     117         if not self.data_is_clean:
# --> 118             raise ValueError("Clean the data first")
#     119         dataframes = self.__load_clean_data()
#     120         # Convert 'Timestamp' to datetime type and set it as index
#
# ValueError: Clean the data first

# %%
processor.clean_files()

# %%
data = processor.get_clean_data()
data
# Out:
#                                  Row   StimType  Duration SourceStimuliName  \
# Timestamp
# 1970-01-01 00:00:00.000000296     13  TestImage    6000.0         1440_8.19
# 1970-01-01 00:00:00.000000302     14        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000000310     15        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000000317     16        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000000325     17        NaN       NaN         1440_8.19
# ...                              ...        ...       ...               ...
# 1970-01-01 00:00:00.000090991  14362        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000090992  14363        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000091000  14364        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000091007  14365        NaN       NaN         1440_8.19
# 1970-01-01 00:00:00.000091015  14366        NaN       NaN         1440_8.19
#
#                               CollectionPhase  SlideEvent Participant  \
# Timestamp
# 1970-01-01 00:00:00.000000296  StimuliDisplay  StartMedia          r3
# 1970-01-01 00:00:00.000000302             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000000310             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000000317             NaN  StartMedia          r3
# 1970-01-01 00:00:00.000000325             NaN  StartMedia          r3
# ...                                       ...         ...         ...
# 1970-01-01 00:00:00.000090991             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000090992             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000091000             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000091007             NaN  StartMedia          R2
# 1970-01-01 00:00:00.000091015             NaN  StartMedia          R2
#
#                                SampleNumber  SampleNumber.1  Anger  ...  \
# Timestamp                                                           ...
# 1970-01-01 00:00:00.000000296           NaN             NaN    NaN  ...
# 1970-01-01 00:00:00.000000302           NaN         99092.0    NaN  ...
# 1970-01-01 00:00:00.000000310           NaN         99093.0    NaN  ...
# 1970-01-01 00:00:00.000000317           NaN         99094.0    NaN  ...
# 1970-01-01 00:00:00.000000325           NaN         99095.0    NaN  ...
# ...                                     ...             ...    ...  ...
# 1970-01-01 00:00:00.000090991         177.0             NaN    NaN  ...
# 1970-01-01 00:00:00.000090992           NaN         87500.0    NaN  ...
# 1970-01-01 00:00:00.000091000           NaN         87501.0    NaN  ...
# 1970-01-01 00:00:00.000091007           NaN         87502.0    NaN  ...
# 1970-01-01 00:00:00.000091015           NaN         87503.0    NaN  ...
#
#                                Confusion  Neutral  GSR RAW  \
# Timestamp
# 1970-01-01 00:00:00.000000296        NaN      NaN      NaN
# 1970-01-01 00:00:00.000000302        NaN      NaN  51565.0
# 1970-01-01 00:00:00.000000310        NaN      NaN  51562.0
# 1970-01-01 00:00:00.000000317        NaN      NaN  51568.0
# 1970-01-01 00:00:00.000000325        NaN      NaN  51567.0
# ...                                  ...      ...      ...
# 1970-01-01 00:00:00.000090991        NaN      NaN      NaN
# 1970-01-01 00:00:00.000090992        NaN      NaN  35810.0
# 1970-01-01 00:00:00.000091000        NaN      NaN  35811.0
# 1970-01-01 00:00:00.000091007        NaN      NaN  35808.0
# 1970-01-01 00:00:00.000091015        NaN      NaN  35810.0
#
#                                GSR Resistance CAL  GSR Conductance CAL  \
# Timestamp
# 1970-01-01 00:00:00.000000296                 NaN                  NaN
# 1970-01-01 00:00:00.000000302         1301.502456             0.768343
# 1970-01-01 00:00:00.000000310         1303.762663             0.767011
# 1970-01-01 00:00:00.000000317         1299.250072             0.769675
# 1970-01-01 00:00:00.000000325         1300.000000             0.769231
# ...                                           ...                  ...
# 1970-01-01 00:00:00.000090991                 NaN                  NaN
# 1970-01-01 00:00:00.000090992          289.256198             3.457143
# 1970-01-01 00:00:00.000091000          289.133658             3.458608
# 1970-01-01 00:00:00.000091007          289.501591             3.454212
# 1970-01-01 00:00:00.000091015          289.256198             3.457143
#
#                                Heart Rate PPG ALG   GSR Raw  GSR Interpolated  \
# Timestamp
# 1970-01-01 00:00:00.000000296                 NaN       NaN               NaN
# 1970-01-01 00:00:00.000000302                -1.0  0.768343          0.768343
# 1970-01-01 00:00:00.000000310                -1.0  0.767011          0.767011
# 1970-01-01 00:00:00.000000317                -1.0  0.769675          0.769675
# 1970-01-01 00:00:00.000000325                -1.0  0.769231          0.769231
# ...                                           ...       ...               ...
# 1970-01-01 00:00:00.000090991                 NaN       NaN               NaN
# 1970-01-01 00:00:00.000090992                89.0  3.457143          3.457143
# 1970-01-01 00:00:00.000091000                89.0  3.458608          3.458608
# 1970-01-01 00:00:00.000091007                89.0  3.454212          3.454212
# 1970-01-01 00:00:00.000091015                89.0  3.457143          3.457143
#
#                                Tonic Signal  Phasic Signal
# Timestamp
# 1970-01-01 00:00:00.000000296           NaN            NaN
# 1970-01-01 00:00:00.000000302      0.767011       0.000063
# 1970-01-01 00:00:00.000000310      0.768343       0.000049
# 1970-01-01 00:00:00.000000317      0.768343       0.000039
# 1970-01-01 00:00:00.000000325      0.768343       0.000274
# ...                                     ...            ...
# 1970-01-01 00:00:00.000090991           NaN            NaN
# 1970-01-01 00:00:00.000090992      3.458608      -0.001673
# 1970-01-01 00:00:00.000091000      3.458608      -0.001467
# 1970-01-01 00:00:00.000091007      3.458608      -0.001627
# 1970-01-01 00:00:00.000091015      3.458608      -0.001913
#
# [28435 rows x 29 columns]
